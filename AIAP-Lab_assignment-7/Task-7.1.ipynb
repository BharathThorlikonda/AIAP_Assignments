# %% [markdown]
# # **Task Description#1**

# %% [markdown]
# **Error Explanation (before fix):**
#
# The error you encountered was a `SyntaxError: invalid syntax`. This was caused by the missing colon `:` at the end of the function definition `def add(a, b)`. In Python, function definitions must end with a colon to indicate the start of the function's code block.

# %%
# Faulty Code (Syntax Error)
def add(a, b):
    return a + b
